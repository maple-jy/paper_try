# %% [markdown]
# <a href="https://colab.research.google.com/github/maple-jy/paper_try/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 加载Google云盘里的数据集文件

# %%
import os
from google.colab import drive
drive.mount('/gdrive')
os.symlink('/gdrive/My Drive', '/content/gdrive')
# !ls -l /content/gdrive/
# Out:
# Mounted at /gdrive
# total 4229778
# drwx------ 2 root root       4096 Feb 20 12:15 'Colab Notebooks'
# -rw------- 1 root root 4331283523 Mar  4 12:16  data.zip
# drwx------ 2 root root       4096 Mar  4 01:36  plants_disease_detection-master
# -rw------- 1 root root        306 Mar  4 06:29  Untitled

# %% [markdown]
# # 加载代码

# %%
# !git clone https://github.com/spytensor/plants_disease_detection
# Out:
# Cloning into 'plants_disease_detection'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 76 (delta 0), reused 1 (delta 0), pack-reused 73
# Unpacking objects: 100% (76/76), 25.44 KiB | 1.21 MiB/s, done.

# %% [markdown]
# # 解压数据集

# %%
# !unzip -uq "/content/gdrive/data.zip" -d "/content/plants_disease_detection/data/"

# %% [markdown]
# # 重新安装openCV

# %% [markdown]
# **卸载原有的openCV**

# %%
# !pip uninstall opencv
# Out:
# WARNING: Skipping opencv as it is not installed.

# %% [markdown]
# **安装整个openCV库**

# %%
# !pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 运行数据集迁移到新的训练集文件和分类

# %%
# !python "/content/plants_disease_detection/move.py"
# Out:
#   6% 2248/36258 [00:03<00:58, 586.23it/s]
# Traceback (most recent call last):
#   File "/content/plants_disease_detection/move.py", line 29, in <module>
#     shutil.copy(origin_path,save_path)
#   File "/usr/lib/python3.9/shutil.py", line 427, in copy
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#   File "/usr/lib/python3.9/shutil.py", line 277, in copyfile
#     _fastcopy_sendfile(fsrc, fdst)
#   File "/usr/lib/python3.9/shutil.py", line 152, in _fastcopy_sendfile
#     sent = os.sendfile(outfd, infd, offset, blocksize)
# KeyboardInterrupt
# ^C

# %% [markdown]
# **数据集预处理**

# %%
# !python "/content/plants_disease_detection/data_aug.py"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# convert pictures :31049 size:(256, 355) mode:RGB
# convert pictures :31050 size:(256, 517) mode:RGB
# convert pictures :31051 size:(256, 434) mode:RGB
# convert pictures :31052 size:(256, 382) mode:RGB
# convert pictures :31053 size:(256, 494) mode:RGB
# convert pictures :31054 size:(256, 389) mode:RGB
# convert pictures :31055 size:(256, 492) mode:RGB
# convert pictures :31056 size:(256, 503) mode:RGB
# convert pictures :31057 size:(256, 492) mode:RGB
# convert pictures :31058 size:(256, 449) mode:RGB
# convert pictures :31059 size:(256, 402) mode:RGB
# convert pictures :31060 size:(256, 458) mode:RGB
# convert pictures :31061 size:(256, 494) mode:RGB
# convert pictures :31062 size:(256, 616) mode:RGB
# convert pictures :31063 size:(256, 415) mode:RGB
# convert pictures :31064 size:(256, 373) mode:RGB
# convert pictures :31065 size:(256, 586) mode:RGB
# convert pictures :31066 size:(256, 378) mode:RGB
# convert pictures :31067 size:(256, 367) mode:RGB
# ...

# %% [markdown]
# # 开始训练

# %%
# !cd dir plants_disease_detection '/content/gdrive'
# Out:
# /bin/bash: line 0: cd: too many arguments

# %%
# !cd dir aug '/content/gdrive'
# Out:
# /bin/bash: line 0: cd: too many arguments

# %%
# !python "/content/plants_disease_detection/main.py"
# Out:
# True
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 240MB/s]
#
# ----------------------------------------------- [START 2023-04-02 14:32:40] ---------------------------------------------------
#
# loading train dataset
# 100% 288384/288384 [00:00<00:00, 1534185.38it/s]
# ** start training here! **
#                            |------------ VALID -------------|----------- TRAIN -------------|------Accuracy------|------------|
# lr       iter     epoch    | loss   top-1  top-2            | loss   top-1  top-2           |    Current Best    | time       |
# -------------------------------------------------------------------------------------------------------------------------------
# 0.0001   0.1    0.0        | inf  0.000  0.000         | 0.949  69.753  87.518         |         0         |  0 hr 06 minTraceback (most recent call last):
# ...
